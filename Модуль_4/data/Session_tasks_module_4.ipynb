# %%
import pandas as pd
city_bike = pd.read_csv('C:/Users/U_M1P8G/Desktop/IDE/Python_for_data_analysis/Модуль_4/data/citibike-tripdata.csv', sep=',')

# %%
city_bike.head()
# Out:
#                   starttime                  stoptime  start station id  \
# 0  2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340             252.0
# 1  2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810             314.0
# 2  2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470            3142.0
# 3  2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830             308.0
# 4  2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080             345.0
#
#                 start station name  start station latitude  \
# 0     MacDougal St & Washington Sq               40.732264
# 1  Cadman Plaza West & Montague St               40.693830
# 2                  1 Ave & E 62 St               40.761227
# 3          St James Pl & Oliver St               40.713079
# 4                  W 13 St & 6 Ave               40.736494
#
#    start station longitude  end station id            end station name  \
# 0               -73.998522           366.0    Clinton Ave & Myrtle Ave
# ...

# %%
city_bike['start station id'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 300000 entries, 0 to 299999
# Series name: start station id
# Non-Null Count   Dtype
# --------------   -----
# 299831 non-null  float64
# dtypes: float64(1)
# memory usage: 2.3 MB

# %%
city_bike['starttime'].dtype
city_bike['starttime'].info()
city_bike['stoptime'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 300000 entries, 0 to 299999
# Series name: starttime
# Non-Null Count   Dtype
# --------------   -----
# 300000 non-null  object
# dtypes: object(1)
# memory usage: 2.3+ MB
# <class 'pandas.core.series.Series'>
# RangeIndex: 300000 entries, 0 to 299999
# Series name: stoptime
# Non-Null Count   Dtype
# --------------   -----
# 300000 non-null  object
# dtypes: object(1)
# memory usage: 2.3+ MB

# %%
city_bike['start station id'].value_counts()
# Out:
# start station id
# 281.0     1928
# 2006.0    1909
# 519.0     1873
# 514.0     1845
# 426.0     1835
#           ...
# 3432.0      15
# 3599.0      11
# 2005.0       9
# 3704.0       7
# 3583.0       6
# Name: count, Length: 759, dtype: int64

# %%
city_bike['bikeid'].value_counts()
# Out:
# bikeid
# 33887    107
# 34358    104
# 34159    103
# 34258    103
# 34730    102
#         ...
# 18083      1
# 17567      1
# 15122      1
# 15681      1
# 25794      1
# Name: count, Length: 10004, dtype: int64

# %%
city_bike['usertype'].mode()
# Out:
# 0    Subscriber
# Name: usertype, dtype: object

# %%
city_bike[city_bike['usertype']=='Subscriber'].shape[0]*100/city_bike.shape[0]
# Out:
# 77.40066666666667

# %%
print("Пропущенные значения:", city_bike['usertype'].isna().sum())
# Out:
# Пропущенные значения: 0

# %%
print("Уникальные значения:", city_bike['usertype'].unique())
# Out:
# Уникальные значения: ['Subscriber' 'Customer']

# %%
user_type_share = city_bike['usertype'].value_counts(normalize=True)
dominant_type_share = user_type_share.max()

# Округляем до сотых
answer = round(dominant_type_share, 2)
print(f"Ответ: {answer}")
# Out:
# Ответ: 0.77

# %%
city_bike['gender'].value_counts()
# Out:
# gender
# 1    183582
# 2     74506
# 0     41912
# Name: count, dtype: int64

# %%
print(city_bike['start station id'].nunique())
print(city_bike['end station id'].nunique())
# Out:
# 759
# 765

# %%
city_bike['birth year']
city_bike['starttime']=pd.to_datetime(city_bike['starttime'])
city_bike['age']=city_bike['starttime'].dt.year - city_bike['birth year']
city_bike['age'].min()
# Out:
# np.int64(16)

# %%
city_bike['start station name'].value_counts()
# Out:
# start station name
# Grand Army Plaza & Central Park S    1928
# Central Park S & 6 Ave               1909
# Pershing Square North                1873
# 12 Ave & W 40 St                     1845
# West St & Chambers St                1835
#                                      ...
# NYCBS Depot - GOW                      15
# Franklin Ave & Empire Blvd             11
# Railroad Ave & Kay Ave                  9
# 47 Ave & Skillman Ave                   7
# Eastern Pkwy & Washington Ave           6
# Name: count, Length: 759, dtype: int64

# %%
city_bike['end station name'].mode()
# Out:
# 0    West St & Chambers St
# Name: end station name, dtype: object

# %%
city_bike.drop(['start station id', 'end station id'], axis = 1, inplace = True)

# %%
city_bike.shape[1]
# Out:
# 12

# %%
city_bike['age'] = 2018-city_bike['birth year']
city_bike['age']
city_bike.drop(['birth year'], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\U_M1P8G\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'birth year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ...

# %%
city_bike[city_bike['age']>60].shape[0]
# Out:
# 11837

# %%
city_bike['stoptime']=pd.to_datetime(city_bike['stoptime'])

# %%
trip_duration = (city_bike['stoptime'] - city_bike['starttime']).dt.total_seconds()/60
trip_duration
# Out:
# 0          27.256083
# 1           2.203333
# 2          55.631633
# 3           7.280617
# 4         140.966550
#              ...
# 299995      7.394133
# 299996     11.552300
# 299997      5.216617
# 299998     56.001533
# 299999      3.750850
# Length: 300000, dtype: float64
